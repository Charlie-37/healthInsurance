# %%
import  pandas as pd
df = pd.read_excel('sampledatainsurance.xlsx','PolicyData')
print(df)
# print(df['State'])
# Out:
#      Policy     Expiry Location State     Region  InsuredValue Construction  \
# 0    100242 2021-01-02    Urban    NY       East       1617630        Frame
# 1    100314 2021-01-02    Urban    NY       East       8678500  Fire Resist
# 2    100359 2021-01-02    Rural    WI    Midwest       2052660        Frame
# 3    100315 2021-01-03    Urban    NY       East      17580000        Frame
# 4    100385 2021-01-03    Urban    NY       East       1925000      Masonry
# ..      ...        ...      ...   ...        ...           ...          ...
# 495  101121 2021-12-31    Urban    VT  Northeast       4101750  Fire Resist
# 496  101122 2021-12-31    Urban    OH    Central       1739100        Frame
# 497  101123 2021-12-31    Urban    NY       East       2250000        Frame
# 498  101125 2021-12-31    Urban    NY       East      16482200        Frame
# 499  101126 2021-12-31    Urban    WI    Midwest       1776800        Frame
#
#     BusinessType Earthquake Flood
# ...

# %%
for i in range(0,len(df['State'])):
   if df['State'][i] == 'NY':
      # print(df['InsuredValue'][i],df['Region'][i])
      print(df.loc[i])
# Out:
# Policy                       100242
# Expiry          2021-01-02 00:00:00
# Location                      Urban
# State                            NY
# Region                         East
# InsuredValue                1617630
# Construction                  Frame
# BusinessType                 Retail
# Earthquake                        N
# Flood                             N
# Name: 0, dtype: object
# Policy                       100314
# Expiry          2021-01-02 00:00:00
# Location                      Urban
# State                            NY
# Region                         East
# InsuredValue                8678500
# Construction            Fire Resist
# BusinessType              Apartment
# Earthquake                        Y
# Flood                             Y
# Name: 1, dtype: object
# Policy                       100315
# Expiry          2021-01-03 00:00:00
# Location                      Urban
# State                            NY
# Region                         East
# ...

# %%
kp = df[df['State'] == 'NY']
kp
# Out:
#      Policy     Expiry Location State Region  InsuredValue Construction  \
# 0    100242 2021-01-02    Urban    NY   East       1617630        Frame
# 1    100314 2021-01-02    Urban    NY   East       8678500  Fire Resist
# 3    100315 2021-01-03    Urban    NY   East      17580000        Frame
# 4    100385 2021-01-03    Urban    NY   East       1925000      Masonry
# 7    100264 2021-01-07    Rural    NY   East       2219900        Frame
# ..      ...        ...      ...   ...    ...           ...          ...
# 492  100389 2021-12-30    Urban    NY   East       1480000  Fire Resist
# 493  101117 2021-12-30    Urban    NY   East       9050000        Frame
# 494  101120 2021-12-30    Rural    NY   East       1480755        Frame
# 497  101123 2021-12-31    Urban    NY   East       2250000        Frame
# 498  101125 2021-12-31    Urban    NY   East      16482200        Frame
#
#     BusinessType Earthquake Flood
# 0         Retail          N     N
# ...

# %%
print(df[['InsuredValue' , 'Region']])
# Out:
#      InsuredValue     Region
# 0         1617630       East
# 1         8678500       East
# 2         2052660    Midwest
# 3        17580000       East
# 4         1925000       East
# ..            ...        ...
# 495       4101750  Northeast
# 496       1739100    Central
# 497       2250000       East
# 498      16482200       East
# 499       1776800    Midwest
#
# [500 rows x 2 columns]

# %% [markdown]
# for i in df:
#    if df['State']   == 'NY':
#        print(df['InsuredValue'])
